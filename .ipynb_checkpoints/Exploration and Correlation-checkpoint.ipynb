# %% [markdown]
# # Exploration and Correlation Notebook
# **Adam Fletcher** <br>
# 08 APR 19 <br>
# Version 1 <br>
# <br>
# Useful Link for making plots in Matplotlib:
# > http://scipy-lectures.org/intro/matplotlib/matplotlib.html
#
# **TODO:**
# - Descriptive Statistics for Univariate Statistics (Mean, Median, Mode, Variance, SD, SE)
# - Display completeness of data (eg. showing missing values)
# - Calculate outliers
# - Hypothesis and AB tests
#
# ### Table of Contents
# - [Data Import](#Data_Import)
# - [Data Exploration](#Data_Exploration)
# - [Univariate Analysis](#Univariate_Analysis)
# - [Multivariate Analysis](#Multivariate_Analysis)
# - [Correlation](#Correlation)
#
# ### Prerequisites

# %%
# !pip install pandas
# %matplotlib inline

import random
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import statistics
import numpy as np
import scipy
from scipy import stats
from IPython.display import display, HTML
import seaborn
# Out:
# Requirement already satisfied: pandas in /Users/adam/anaconda3/lib/python3.7/site-packages (0.23.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/adam/anaconda3/lib/python3.7/site-packages (from pandas) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /Users/adam/anaconda3/lib/python3.7/site-packages (from pandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in /Users/adam/anaconda3/lib/python3.7/site-packages (from pandas) (1.15.4)
# Requirement already satisfied: six>=1.5 in /Users/adam/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)

# %% [markdown]
# <a id='Data_Import'></a>
# ### Data Import
# Data should be imported with the __variable name = data__

# %%
# Data Import
data = pd.read_csv('/Users/adam/Downloads/trip.csv')

data = pd.read_excel('/Users/adam/Downloads/Concrete_Data.xls')
data.columns = ['cement_component', 'furnace_slag', 'flay_ash', 'water_component', 'superplasticizer', 'coarse_aggregate', 'fine_aggregate', 'age', 'concrete_strength']


# Print info about the imported data
print("Length of Data Frame:", len(data), "rows and", len(data.columns), "columns")
data.head()
# Out:
# Length of Data Frame: 1030 rows and 9 columns
#    cement_component  furnace_slag  flay_ash  water_component  \
# 0             540.0           0.0       0.0            162.0
# 1             540.0           0.0       0.0            162.0
# 2             332.5         142.5       0.0            228.0
# 3             332.5         142.5       0.0            228.0
# 4             198.6         132.4       0.0            192.0
#
#    superplasticizer  coarse_aggregate  fine_aggregate  age  concrete_strength
# 0               2.5            1040.0           676.0   28          79.986111
# 1               2.5            1055.0           676.0   28          61.887366
# 2               0.0             932.0           594.0  270          40.269535
# 3               0.0             932.0           594.0  365          41.052780
# 4               0.0             978.4           825.5  360          44.296075

# %% [markdown]
# <a id='Data_Exploration'></a>
# ### Data Exploration
#
# Quickly look at the Distribution for **specific variables** <br>
#
# <a id='Univariate_Analysis'></a>
# #### Univariate Analysis
#
# TODO: Add Descriptive Statistics
#
# **Barcharts**

# %%
selected = ['from_station_id', 'to_station_id', 'usertype', 'gender', 'birthyear']
plt.figure(figsize=(20,30))
plot_count = 1

for feature in selected:
        plt.subplot(3, 3, plot_count) #Adjust grid to make room for more plots/ change shape of matrix
        plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.5) #Adjust the spacing between plots
        groupby_var = data.groupby(feature).size()
        groupby_var.plot.bar(title = feature.replace('_',' ').title())
        plt.ylabel('Number of Occurances')
        plot_count+=1
plt.show()

# %% [markdown]
# <a id='Multivariate_Analysis'></a>
# #### Multivariate Plots

# %% [markdown]
# **Scatterplots:** Against one comparable variable

# %%
plt.figure(figsize=(15,10.5))
plot_count = 1

for feature in list(data.columns):
        data_ = data[data[feature] != 0] #Remove 0's from Data
        plt.subplot(3, 3, plot_count)
        seaborn.regplot(data_[feature], data_['concrete_strength']) #regplot adds a linear regression line
        plt.xlabel(feature.replace('_',' ').title())
        plt.ylabel('Concrete strength')
        plot_count+=1
plt.show()

# %% [markdown]
# **Pair Plots:** All variables plotted against one another

# %%
data = data.dropna()
seaborn.pairplot(data, kind='reg')
plt.show()

# %% [markdown]
# <a id='Correlation'></a>
# ### Correlation
#
# 3 Major Tests for Correlation:
#
# - Pearsons Correlation - Most Common, Normal Distibuted **Quantitative** variables
# >https://statistics.laerd.com/statistical-guides/pearson-correlation-coefficient-statistical-guide.php
# - Kendall Rank Correlation - (Non-parametric, **non-normal distribution**, **Quantitative** variables
# >https://statistics.laerd.com/spss-tutorials/kendalls-tau-b-using-spss-statistics.php
# - Spearman Rank Correlation - Non-parametrics, **non-normal distribution**, **Ordinal/Categorical** variables
# >https://statistics.laerd.com/statistical-guides/spearmans-rank-order-correlation-statistical-guide.php

# %% [markdown]
# **Correlation Tables**
#
# data.corr() --> add in 'pearson', 'kendal', 'spearman'

# %%
data.corr('pearson')
# Out:
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.275193 -0.397475        -0.081544
# furnace_slag              -0.275193      1.000000 -0.323569         0.107286
# flay_ash                  -0.397475     -0.323569  1.000000        -0.257044
# water_component           -0.081544      0.107286 -0.257044         1.000000
# superplasticizer           0.092771      0.043376  0.377340        -0.657464
# coarse_aggregate          -0.109356     -0.283998 -0.009977        -0.182312
# fine_aggregate            -0.222720     -0.281593  0.079076        -0.450635
# age                        0.081947     -0.044246 -0.154370         0.277604
# concrete_strength          0.497833      0.134824 -0.105753        -0.289613
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  \
# cement_component           0.092771         -0.109356       -0.222720
# furnace_slag               0.043376         -0.283998       -0.281593
# flay_ash                   0.377340         -0.009977        0.079076
# water_component           -0.657464         -0.182312       -0.450635
# superplasticizer           1.000000         -0.266303        0.222501
# coarse_aggregate          -0.266303          1.000000       -0.178506
# fine_aggregate             0.222501         -0.178506        1.000000
# age                       -0.192717         -0.003016       -0.156094
# concrete_strength          0.366102         -0.164928       -0.167249
#
#                         age  concrete_strength
# cement_component   0.081947           0.497833
# furnace_slag      -0.044246           0.134824
# flay_ash          -0.154370          -0.105753
# water_component    0.277604          -0.289613
# superplasticizer  -0.192717           0.366102
# coarse_aggregate  -0.003016          -0.164928
# fine_aggregate    -0.156094          -0.167249
# age                1.000000           0.328877
# concrete_strength  0.328877           1.000000

# %% [markdown]
# **Correlation over specific Category** <br>
#
# In this example 'age' is a categorical variable and so exploring how multivariate correlation changes with age is a good idea

# %%
for value in data['age'].unique():
    print("")
    print ("Age: ",  value)
    data_map = data['age'] == value
    data_ = data[data_map]
    display(data_.corr())
    
## How do I make this occur on just one line??
# Out:
# Age:  28
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.384743 -0.398613        -0.190272
# furnace_slag              -0.384743      1.000000 -0.251259         0.123474
# flay_ash                  -0.398613     -0.251259  1.000000        -0.025742
# water_component           -0.190272      0.123474 -0.025742         1.000000
# superplasticizer          -0.046934      0.024699  0.462265        -0.443441
# coarse_aggregate           0.020778     -0.249908 -0.255168        -0.272437
# fine_aggregate            -0.124040     -0.262033 -0.051904        -0.367800
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.666058      0.141404 -0.269446        -0.398556
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component          -0.046934          0.020778       -0.124040  NaN
# furnace_slag               0.024699         -0.249908       -0.262033  NaN
# flay_ash                   0.462265         -0.255168       -0.051904  NaN
# water_component           -0.443441         -0.272437       -0.367800  NaN
# superplasticizer           1.000000         -0.330106        0.094681  NaN
# coarse_aggregate          -0.330106          1.000000       -0.179138  NaN
# fine_aggregate             0.094681         -0.179138        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength          0.213257         -0.120295       -0.138026  NaN
#
#                    concrete_strength
# cement_component            0.666058
# furnace_slag                0.141404
# flay_ash                   -0.269446
# water_component            -0.398556
# superplasticizer            0.213257
# coarse_aggregate           -0.120295
# fine_aggregate             -0.138026
# age                              NaN
# concrete_strength           1.000000
# Age:  270
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.854722       NaN        -0.723652
# furnace_slag              -0.854722      1.000000       NaN         0.494028
# flay_ash                        NaN           NaN       NaN              NaN
# water_component           -0.723652      0.494028       NaN         1.000000
# superplasticizer                NaN           NaN       NaN              NaN
# coarse_aggregate           0.735655     -0.517340       NaN        -0.954939
# fine_aggregate            -0.464926      0.004475       NaN         0.223026
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.502813     -0.555982       NaN        -0.832452
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component                NaN          0.735655       -0.464926  NaN
# furnace_slag                    NaN         -0.517340        0.004475  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component                 NaN         -0.954939        0.223026  NaN
# superplasticizer                NaN               NaN             NaN  NaN
# coarse_aggregate                NaN          1.000000       -0.233550  NaN
# fine_aggregate                  NaN         -0.233550        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength               NaN          0.760874        0.323938  NaN
#
#                    concrete_strength
# cement_component            0.502813
# furnace_slag               -0.555982
# flay_ash                         NaN
# water_component            -0.832452
# superplasticizer                 NaN
# coarse_aggregate            0.760874
# fine_aggregate              0.323938
# age                              NaN
# concrete_strength           1.000000
# Age:  365
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.460383       NaN         0.294889
# furnace_slag              -0.460383      1.000000       NaN         0.556254
# flay_ash                        NaN           NaN       NaN              NaN
# water_component            0.294889      0.556254       NaN         1.000000
# superplasticizer                NaN           NaN       NaN              NaN
# coarse_aggregate          -0.291476     -0.558134       NaN        -0.996632
# fine_aggregate            -0.462977     -0.551313       NaN        -0.921502
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.139775      0.297434       NaN         0.759721
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component                NaN         -0.291476       -0.462977  NaN
# furnace_slag                    NaN         -0.558134       -0.551313  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component                 NaN         -0.996632       -0.921502  NaN
# superplasticizer                NaN               NaN             NaN  NaN
# coarse_aggregate                NaN          1.000000        0.920828  NaN
# fine_aggregate                  NaN          0.920828        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength               NaN         -0.755935       -0.584247  NaN
#
#                    concrete_strength
# cement_component            0.139775
# furnace_slag                0.297434
# flay_ash                         NaN
# water_component             0.759721
# superplasticizer                 NaN
# coarse_aggregate           -0.755935
# fine_aggregate             -0.584247
# age                              NaN
# concrete_strength           1.000000
# Age:  360
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.956051       NaN        -0.056510
# furnace_slag              -0.956051      1.000000       NaN         0.304838
# flay_ash                        NaN           NaN       NaN              NaN
# water_component           -0.056510      0.304838       NaN         1.000000
# superplasticizer                NaN           NaN       NaN              NaN
# coarse_aggregate          -0.234431      0.437862       NaN         0.386282
# fine_aggregate             0.241959     -0.501553       NaN        -0.646709
# age                             NaN           NaN       NaN              NaN
# concrete_strength         -0.458624      0.688705       NaN         0.821970
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component                NaN         -0.234431        0.241959  NaN
# furnace_slag                    NaN          0.437862       -0.501553  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component                 NaN          0.386282       -0.646709  NaN
# superplasticizer                NaN               NaN             NaN  NaN
# coarse_aggregate                NaN          1.000000       -0.862527  NaN
# fine_aggregate                  NaN         -0.862527        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength               NaN          0.587255       -0.864842  NaN
#
#                    concrete_strength
# cement_component           -0.458624
# furnace_slag                0.688705
# flay_ash                         NaN
# water_component             0.821970
# superplasticizer                 NaN
# coarse_aggregate            0.587255
# fine_aggregate             -0.864842
# age                              NaN
# concrete_strength           1.000000
# Age:  90
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.697626       NaN         0.055401
# furnace_slag              -0.697626      1.000000       NaN         0.168206
# flay_ash                        NaN           NaN       NaN              NaN
# water_component            0.055401      0.168206       NaN         1.000000
# superplasticizer                NaN           NaN       NaN              NaN
# coarse_aggregate           0.410930     -0.277651       NaN        -0.348867
# fine_aggregate            -0.511413     -0.167426       NaN        -0.597032
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.544400      0.067504       NaN         0.061348
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component                NaN          0.410930       -0.511413  NaN
# furnace_slag                    NaN         -0.277651       -0.167426  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component                 NaN         -0.348867       -0.597032  NaN
# superplasticizer                NaN               NaN             NaN  NaN
# coarse_aggregate                NaN          1.000000       -0.233975  NaN
# fine_aggregate                  NaN         -0.233975        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength               NaN          0.305713       -0.698579  NaN
#
#                    concrete_strength
# cement_component            0.544400
# furnace_slag                0.067504
# flay_ash                         NaN
# water_component             0.061348
# superplasticizer                 NaN
# coarse_aggregate            0.305713
# fine_aggregate             -0.698579
# age                              NaN
# concrete_strength           1.000000
# Age:  180
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.561501       NaN        -0.070164
# furnace_slag              -0.561501      1.000000       NaN         0.433334
# flay_ash                        NaN           NaN       NaN              NaN
# water_component           -0.070164      0.433334       NaN         1.000000
# superplasticizer                NaN           NaN       NaN              NaN
# coarse_aggregate           0.471972     -0.266748       NaN        -0.710245
# fine_aggregate            -0.557392     -0.310023       NaN        -0.607467
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.543898      0.083822       NaN         0.042894
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component                NaN          0.471972       -0.557392  NaN
# furnace_slag                    NaN         -0.266748       -0.310023  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component                 NaN         -0.710245       -0.607467  NaN
# superplasticizer                NaN               NaN             NaN  NaN
# coarse_aggregate                NaN          1.000000       -0.018046  NaN
# fine_aggregate                  NaN         -0.018046        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength               NaN          0.468100       -0.640016  NaN
#
#                    concrete_strength
# cement_component            0.543898
# furnace_slag                0.083822
# flay_ash                         NaN
# water_component             0.042894
# superplasticizer                 NaN
# coarse_aggregate            0.468100
# fine_aggregate             -0.640016
# age                              NaN
# concrete_strength           1.000000
# Age:  3
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.151812 -0.323953        -0.144231
# furnace_slag              -0.151812      1.000000 -0.492215         0.101446
# flay_ash                  -0.323953     -0.492215  1.000000        -0.356057
# water_component           -0.144231      0.101446 -0.356057         1.000000
# superplasticizer           0.318100      0.018370  0.227435        -0.827256
# coarse_aggregate          -0.328120     -0.254222  0.331561        -0.073826
# fine_aggregate            -0.266941     -0.291712  0.032065        -0.252480
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.776874      0.081850 -0.102475        -0.528126
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component           0.318100         -0.328120       -0.266941  NaN
# furnace_slag               0.018370         -0.254222       -0.291712  NaN
# flay_ash                   0.227435          0.331561        0.032065  NaN
# water_component           -0.827256         -0.073826       -0.252480  NaN
# superplasticizer           1.000000         -0.147987        0.164738  NaN
# coarse_aggregate          -0.147987          1.000000       -0.340489  NaN
# fine_aggregate             0.164738         -0.340489        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength          0.655078         -0.237234       -0.215241  NaN
#
#                    concrete_strength
# cement_component            0.776874
# furnace_slag                0.081850
# flay_ash                   -0.102475
# water_component            -0.528126
# superplasticizer            0.655078
# coarse_aggregate           -0.237234
# fine_aggregate             -0.215241
# age                              NaN
# concrete_strength           1.000000
# Age:  7
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.460677  0.246429        -0.368023
# furnace_slag              -0.460677      1.000000 -0.249973         0.033354
# flay_ash                   0.246429     -0.249973  1.000000        -0.177883
# water_component           -0.368023      0.033354 -0.177883         1.000000
# superplasticizer           0.483686      0.080660  0.255174        -0.788701
# coarse_aggregate          -0.203398     -0.251397 -0.346196         0.183300
# fine_aggregate            -0.161178     -0.280708  0.013708        -0.444087
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.759237      0.044205  0.233355        -0.567526
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component           0.483686         -0.203398       -0.161178  NaN
# furnace_slag               0.080660         -0.251397       -0.280708  NaN
# flay_ash                   0.255174         -0.346196        0.013708  NaN
# water_component           -0.788701          0.183300       -0.444087  NaN
# superplasticizer           1.000000         -0.491720        0.249172  NaN
# coarse_aggregate          -0.491720          1.000000       -0.269801  NaN
# fine_aggregate             0.249172         -0.269801        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength          0.756571         -0.453714       -0.145904  NaN
#
#                    concrete_strength
# cement_component            0.759237
# furnace_slag                0.044205
# flay_ash                    0.233355
# water_component            -0.567526
# superplasticizer            0.756571
# coarse_aggregate           -0.453714
# fine_aggregate             -0.145904
# age                              NaN
# concrete_strength           1.000000
# Age:  56
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000      0.293349 -0.621863        -0.074824
# furnace_slag               0.293349      1.000000 -0.684683        -0.131394
# flay_ash                  -0.621863     -0.684683  1.000000         0.085266
# water_component           -0.074824     -0.131394  0.085266         1.000000
# superplasticizer           0.491553      0.309085 -0.455360        -0.701826
# coarse_aggregate          -0.724792     -0.248416  0.415697        -0.028834
# fine_aggregate            -0.134729     -0.337075 -0.013368        -0.347949
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.649630      0.695842 -0.560784        -0.371110
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component           0.491553         -0.724792       -0.134729  NaN
# furnace_slag               0.309085         -0.248416       -0.337075  NaN
# flay_ash                  -0.455360          0.415697       -0.013368  NaN
# water_component           -0.701826         -0.028834       -0.347949  NaN
# superplasticizer           1.000000         -0.325086        0.229850  NaN
# coarse_aggregate          -0.325086          1.000000       -0.244864  NaN
# fine_aggregate             0.229850         -0.244864        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength          0.555580         -0.488220       -0.215662  NaN
#
#                    concrete_strength
# cement_component            0.649630
# furnace_slag                0.695842
# flay_ash                   -0.560784
# water_component            -0.371110
# superplasticizer            0.555580
# coarse_aggregate           -0.488220
# fine_aggregate             -0.215662
# age                              NaN
# concrete_strength           1.000000
# Age:  91
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.800492       NaN        -0.141565
# furnace_slag              -0.800492      1.000000       NaN         0.516226
# flay_ash                        NaN           NaN       NaN              NaN
# water_component           -0.141565      0.516226       NaN         1.000000
# superplasticizer           0.564211     -0.586143       NaN        -0.761429
# coarse_aggregate          -0.531111      0.528088       NaN         0.167816
# fine_aggregate             0.307806     -0.661103       NaN        -0.610502
# age                             NaN           NaN       NaN              NaN
# concrete_strength         -0.255032      0.485364       NaN         0.224500
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component           0.564211         -0.531111        0.307806  NaN
# furnace_slag              -0.586143          0.528088       -0.661103  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component           -0.761429          0.167816       -0.610502  NaN
# superplasticizer           1.000000         -0.348638        0.440092  NaN
# coarse_aggregate          -0.348638          1.000000       -0.804869  NaN
# fine_aggregate             0.440092         -0.804869        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength         -0.258924          0.101946       -0.264333  NaN
#
#                    concrete_strength
# cement_component           -0.255032
# furnace_slag                0.485364
# flay_ash                         NaN
# water_component             0.224500
# superplasticizer           -0.258924
# coarse_aggregate            0.101946
# fine_aggregate             -0.264333
# age                              NaN
# concrete_strength           1.000000
# Age:  14
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.336336 -0.738867         0.430151
# furnace_slag              -0.336336      1.000000  0.102334        -0.129199
# flay_ash                  -0.738867      0.102334  1.000000        -0.602286
# water_component            0.430151     -0.129199 -0.602286         1.000000
# superplasticizer          -0.494376      0.146637  0.612671        -0.730563
# coarse_aggregate           0.122079      0.082675  0.142285        -0.323812
# fine_aggregate            -0.499202     -0.236479  0.159123        -0.243153
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.468993      0.158596 -0.060495        -0.302136
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component          -0.494376          0.122079       -0.499202  NaN
# furnace_slag               0.146637          0.082675       -0.236479  NaN
# flay_ash                   0.612671          0.142285        0.159123  NaN
# water_component           -0.730563         -0.323812       -0.243153  NaN
# superplasticizer           1.000000          0.166611        0.297261  NaN
# coarse_aggregate           0.166611          1.000000       -0.619578  NaN
# fine_aggregate             0.297261         -0.619578        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength          0.257532          0.283839       -0.386117  NaN
#
#                    concrete_strength
# cement_component            0.468993
# furnace_slag                0.158596
# flay_ash                   -0.060495
# water_component            -0.302136
# superplasticizer            0.257532
# coarse_aggregate            0.283839
# fine_aggregate             -0.386117
# age                              NaN
# concrete_strength           1.000000
# Age:  100
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000     -0.381797 -0.604854         0.314853
# furnace_slag              -0.381797      1.000000 -0.111061        -0.025329
# flay_ash                  -0.604854     -0.111061  1.000000        -0.408403
# water_component            0.314853     -0.025329 -0.408403         1.000000
# superplasticizer           0.071172     -0.018375  0.107894        -0.638380
# coarse_aggregate          -0.294294      0.087813  0.180887        -0.351380
# fine_aggregate             0.104182     -0.432879 -0.209615        -0.213225
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.197468      0.412237 -0.066620        -0.412996
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component           0.071172         -0.294294        0.104182  NaN
# furnace_slag              -0.018375          0.087813       -0.432879  NaN
# flay_ash                   0.107894          0.180887       -0.209615  NaN
# water_component           -0.638380         -0.351380       -0.213225  NaN
# superplasticizer           1.000000          0.216234        0.118325  NaN
# coarse_aggregate           0.216234          1.000000       -0.521632  NaN
# fine_aggregate             0.118325         -0.521632        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength          0.616746          0.110341       -0.189098  NaN
#
#                    concrete_strength
# cement_component            0.197468
# furnace_slag                0.412237
# flay_ash                   -0.066620
# water_component            -0.412996
# superplasticizer            0.616746
# coarse_aggregate            0.110341
# fine_aggregate             -0.189098
# age                              NaN
# concrete_strength           1.000000
# Age:  120
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component           1.000000           NaN       NaN              NaN
# furnace_slag                    NaN           NaN       NaN              NaN
# flay_ash                        NaN           NaN       NaN              NaN
# water_component                 NaN           NaN       NaN              NaN
# superplasticizer                NaN           NaN       NaN              NaN
# coarse_aggregate           0.962066           NaN       NaN              NaN
# fine_aggregate            -0.991987           NaN       NaN              NaN
# age                             NaN           NaN       NaN              NaN
# concrete_strength          0.968063           NaN       NaN              NaN
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component                NaN          0.962066       -0.991987  NaN
# furnace_slag                    NaN               NaN             NaN  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component                 NaN               NaN             NaN  NaN
# superplasticizer                NaN               NaN             NaN  NaN
# coarse_aggregate                NaN          1.000000       -0.988824  NaN
# fine_aggregate                  NaN         -0.988824        1.000000  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength               NaN          0.999738       -0.991980  NaN
#
#                    concrete_strength
# cement_component            0.968063
# furnace_slag                     NaN
# flay_ash                         NaN
# water_component                  NaN
# superplasticizer                 NaN
# coarse_aggregate            0.999738
# fine_aggregate             -0.991980
# age                              NaN
# concrete_strength           1.000000
# Age:  1
#                    cement_component  furnace_slag  flay_ash  water_component  \
# cement_component                1.0           NaN       NaN              1.0
# furnace_slag                    NaN           NaN       NaN              NaN
# flay_ash                        NaN           NaN       NaN              NaN
# water_component                 1.0           NaN       NaN              1.0
# superplasticizer                NaN           NaN       NaN              NaN
# coarse_aggregate                1.0           NaN       NaN              1.0
# fine_aggregate                 -1.0           NaN       NaN             -1.0
# age                             NaN           NaN       NaN              NaN
# concrete_strength               1.0           NaN       NaN              1.0
#
#                    superplasticizer  coarse_aggregate  fine_aggregate  age  \
# cement_component                NaN               1.0            -1.0  NaN
# furnace_slag                    NaN               NaN             NaN  NaN
# flay_ash                        NaN               NaN             NaN  NaN
# water_component                 NaN               1.0            -1.0  NaN
# superplasticizer                NaN               NaN             NaN  NaN
# coarse_aggregate                NaN               1.0            -1.0  NaN
# fine_aggregate                  NaN              -1.0             1.0  NaN
# age                             NaN               NaN             NaN  NaN
# concrete_strength               NaN               1.0            -1.0  NaN
#
#                    concrete_strength
# cement_component                 1.0
# furnace_slag                     NaN
# flay_ash                         NaN
# water_component                  1.0
# superplasticizer                 NaN
# coarse_aggregate                 1.0
# fine_aggregate                  -1.0
# age                              NaN
# concrete_strength                1.0
